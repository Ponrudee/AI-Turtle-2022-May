# %%
# Connect Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/dataset/Animation
# Out:
# /content/gdrive/MyDrive/dataset/Animation

# %%
import cv2
import numpy as np
import os
from os.path import isfile, join
def convert_frames_to_video(pathIn,pathOut,fps):
    frame_array = []
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
    #for sorting the file names properly
    #files.sort(key = lambda x: int(x[5:-4]))
    for i in range(len(files)):
        filename=pathIn + files[i]
        #reading each files
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
        print(filename)
        #inserting the frames into an image array
        frame_array.append(img)
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
    for i in range(len(frame_array)):
        # writing to a image array
        out.write(frame_array[i])
    out.release()

# %%
pathIn= './NewEdition/TurtleResult/'
pathOut = 'TurtleTest1.mp4'
fps = 2
convert_frames_to_video(pathIn, pathOut, fps)
# Out:
# ./NewEdition/TurtleResult/1.jpg
# ./NewEdition/TurtleResult/2.jpg
# ./NewEdition/TurtleResult/3.jpg
# ./NewEdition/TurtleResult/4.jpg
# ./NewEdition/TurtleResult/5.jpg
# ./NewEdition/TurtleResult/6.jpg
# ./NewEdition/TurtleResult/7.jpg
# ./NewEdition/TurtleResult/8.jpg
# ./NewEdition/TurtleResult/9.jpg
