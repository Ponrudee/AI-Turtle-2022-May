# %%
from google.colab import drive
import os
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/ProjectOutput/GAN_dcganTF/myFlowers/
# Out:
# /content/gdrive/MyDrive/ProjectOutput/GAN_dcganTF/myFlowers

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
index = [1,2500,5000,7500,10000]
images = []
for i in range(5):
  try:
    image = Image.open('image_at_epoch_%04d.png'%(index[i]))
    images.append(image)
  except:
    print("", end="")
print(len(images))
# Out:
# 5

# %%
# %cd /content/gdrive/MyDrive/ProjectOutput/newTF/myFlowers/
# Out:
# /content/gdrive/MyDrive/ProjectOutput/newTF/myFlowers

# %%
for i in range(5):
  images[i].save("%04d.png"%(i))
